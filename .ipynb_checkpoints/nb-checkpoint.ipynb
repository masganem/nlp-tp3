# %% [markdown]
# ## Trabalho Prático III
# ### Aprendizado Profundo para Processamento de Linguagem Natural (2025/2)
# **Aluno:** Marcelo Augusto Salomão Ganem
#
# **Matrícula:** 2020054684
#
# ## Preparações
# aaa
#
# Para instalar as bibliotecas utilizadas, basta executar
# ```bash
# pip install torch transformers tqdm matplotlib
# ```
# em um terminal de comando.

# %%
from collections import defaultdict, Counter
import json
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModelForTokenClassification
import urllib.request
